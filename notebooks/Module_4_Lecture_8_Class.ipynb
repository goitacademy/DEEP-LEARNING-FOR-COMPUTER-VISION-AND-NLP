# %%
import gc
gc.collect()
# Out:
# 0

# %%
import os
import random
from tqdm import tqdm


import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt
import plotly.express as px

import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# loading data

data_dir = '../data'

train_dataset = torchvision.datasets.FashionMNIST(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.FashionMNIST(data_dir, train=False, download=True)

print(train_dataset)
type(train_dataset)
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: ../data
#     Split: Train
# torchvision.datasets.mnist.FashionMNIST

# %%
# display images examples

fig, axs = plt.subplots(5, 5, figsize=(6,6))
for ax in axs.flatten():
    img, label = random.choice(train_dataset)
    ax.imshow(np.array(img), cmap='gist_gray')
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# %%
# data to tensors

train_transform = transforms.Compose([
    transforms.ToTensor(),
])
test_transform = transforms.Compose([
    transforms.ToTensor(),
])

# Set the train transform
train_dataset.transform = train_transform
# Set the test transform
test_dataset.transform = test_transform

# %%
# adding validation split

m=len(train_dataset)

train_data, val_data = random_split(train_dataset, [int(len(train_dataset)*0.8), int(m*0.2)])

batch_size=256

# The dataloaders handle shuffling, batching, etc...
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,shuffle=True)

# %%
class Encoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()
        
        # Convolutional section
        self.encoder_cnn = nn.Sequential(
            # First convolutional layer
            nn.Conv2d(1, 8, 3, stride=2, padding=1),
            #nn.BatchNorm2d(8),
            nn.ReLU(True),
            # Second convolutional layer
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            # Third convolutional layer
            nn.Conv2d(16, 32, 3, stride=2, padding=0),
            #nn.BatchNorm2d(32),
            nn.ReLU(True)
        )
        
        # Flatten layer
        self.flatten = nn.Flatten(start_dim=1)

        # Linear section
        self.encoder_lin = nn.Sequential(
            # First linear layer
            nn.Linear(3 * 3 * 32, 128),
            nn.ReLU(True),
            # Second linear layer
            nn.Linear(128, encoded_space_dim)
        )
        
    def forward(self, x):
        # Apply convolutions
        x = self.encoder_cnn(x)
        # Flatten
        x = self.flatten(x)
        # # Apply linear layers
        x = self.encoder_lin(x)
        return x

# %%
class Decoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim=128):
        super().__init__()

        # Linear section
        self.decoder_lin = nn.Sequential(
            # First linear layer
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            # Second linear layer
            nn.Linear(128, 3 * 3 * 32),
            nn.ReLU(True)
        )

        # Unflatten
        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(32, 3, 3))

        # Convolutional section
        self.decoder_conv = nn.Sequential(
            # First transposed convolution
            nn.ConvTranspose2d(32, 16, 3, stride=2, output_padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            # Second transposed convolution
            nn.ConvTranspose2d(16, 8, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            # Third transposed convolution
            nn.ConvTranspose2d(8, 1, 3, stride=2, padding=1, output_padding=1)
        )
        
    def forward(self, x):
        # Apply linear layers
        x = self.decoder_lin(x)
        # Unflatten
        x = self.unflatten(x)
        # Apply transposed convolutions
        x = self.decoder_conv(x)
        # Apply a sigmoid to force the output to be between 0 and 1 (valid pixel values)
        x = torch.sigmoid(x)
        return x

# %%
# Set the random seed for reproducible results
torch.manual_seed(42)

# Initialize the two networks
dim = 4

encoder = Encoder(encoded_space_dim=dim, fc2_input_dim=128)
decoder = Decoder(encoded_space_dim=dim, fc2_input_dim=128)

# %%
# Example on the untrained model

img, _ = test_dataset[0]
img = img.unsqueeze(0) # Add the batch dimension in the first axis
print('Original image shape:', img.shape)

# Encode the image
img_enc = encoder(img)
print('Encoded image shape:', img_enc.shape)

# Decode the image
dec_img = decoder(img_enc)
print('Decoded image shape:', dec_img.shape)
# Out:
# Original image shape: torch.Size([1, 1, 28, 28])
# Encoded image shape: torch.Size([1, 4])
# Decoded image shape: torch.Size([1, 1, 28, 28])

# %%
# Define the loss function
loss_fn = torch.nn.MSELoss()

# Define an optimizer (both for the encoder and the decoder!)
lr= 0.001

params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

optim = torch.optim.Adam(params_to_optimize, lr=lr, weight_decay=1e-05)

# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

# Move both the encoder and the decoder to the selected device
encoder.to(device)
# Out:
# Selected device: cpu
# Encoder(
#   (encoder_cnn): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (6): ReLU(inplace=True)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (encoder_lin): Sequential(
#     (0): Linear(in_features=288, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=4, bias=True)
#   )
# )

# %%
decoder.to(device)
# Out:
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=288, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(32, 3, 3))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   )
# )

# %%
def train_epoch(encoder, decoder, device, dataloader, loss_fn, optimizer):
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for image_batch, _ in dataloader: # with "_" we just ignore the labels (the second element of the dataloader tuple)
        # Move tensor to the proper device
        image_batch = image_batch.to(device)
        # Encode data
        encoded_data = encoder(image_batch)
        # Decode data
        decoded_data = decoder(encoded_data)
        # Evaluate loss
        loss = loss_fn(decoded_data, image_batch)
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        print('\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)

# %%
def test_epoch(encoder, decoder, device, dataloader, loss_fn):
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    with torch.no_grad(): # No need to track the gradients
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        for image_batch, _ in dataloader:
            # Move tensor to the proper device
            image_batch = image_batch.to(device)
            # Encode data
            encoded_data = encoder(image_batch)
            # Decode data
            decoded_data = decoder(encoded_data)
            # Append the network output and the original image to the lists
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label) 
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %%
def plot_ae_outputs(encoder,decoder,n=5):
    plt.figure(figsize=(10,4.5))
    for i in range(n):
        ax = plt.subplot(2,n,i+1)
        img = test_dataset[i][0].unsqueeze(0).to(device)
        encoder.eval()
        decoder.eval()
        with torch.no_grad():
            rec_img  = decoder(encoder(img))
        plt.imshow(img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)  
        if i == n//2:
            ax.set_title('Original images')
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(rec_img.cpu().squeeze().numpy(), cmap='gist_gray')  
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)  
        if i == n//2:
            ax.set_title('Reconstructed images')
    plt.show()

# %%
num_epochs = 30
history={'train_loss':[],'val_loss':[]}

for epoch in range(num_epochs):
    train_loss = train_epoch(encoder,decoder,device,train_loader,loss_fn,optim)
    val_loss = test_epoch(encoder,decoder,device,valid_loader,loss_fn)
    
    print('\n EPOCH {}/{} \t train loss {:.3f} \t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))
    
    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)
    plot_ae_outputs(encoder,decoder,n=5)
# Out:
# 	 partial train loss (single batch): 0.252832
# 	 partial train loss (single batch): 0.235747
# 	 partial train loss (single batch): 0.236400
# 	 partial train loss (single batch): 0.227767
# 	 partial train loss (single batch): 0.226510
# 	 partial train loss (single batch): 0.217970
# 	 partial train loss (single batch): 0.211242
# 	 partial train loss (single batch): 0.211075
# 	 partial train loss (single batch): 0.215251
# 	 partial train loss (single batch): 0.204518
# 	 partial train loss (single batch): 0.207401
# 	 partial train loss (single batch): 0.202006
# 	 partial train loss (single batch): 0.196923
# 	 partial train loss (single batch): 0.200778
# 	 partial train loss (single batch): 0.192220
# 	 partial train loss (single batch): 0.193445
# 	 partial train loss (single batch): 0.190146
# 	 partial train loss (single batch): 0.182744
# 	 partial train loss (single batch): 0.186428
# 	 partial train loss (single batch): 0.184977
# 	 partial train loss (single batch): 0.185015
# 	 partial train loss (single batch): 0.183935
# 	 partial train loss (single batch): 0.178738
# 	 partial train loss (single batch): 0.181645
# 	 partial train loss (single batch): 0.177888
# 	 partial train loss (single batch): 0.173612
# 	 partial train loss (single batch): 0.175152
# 	 partial train loss (single batch): 0.171911
# 	 partial train loss (single batch): 0.173065
# 	 partial train loss (single batch): 0.172008
# 	 partial train loss (single batch): 0.166906
# 	 partial train loss (single batch): 0.164959
# 	 partial train loss (single batch): 0.167374
# 	 partial train loss (single batch): 0.163956
# 	 partial train loss (single batch): 0.163617
# 	 partial train loss (single batch): 0.169005
# 	 partial train loss (single batch): 0.156387
# 	 partial train loss (single batch): 0.160643
# 	 partial train loss (single batch): 0.158506
# 	 partial train loss (single batch): 0.156652
# 	 partial train loss (single batch): 0.158387
# 	 partial train loss (single batch): 0.154892
# 	 partial train loss (single batch): 0.156544
# 	 partial train loss (single batch): 0.150735
# 	 partial train loss (single batch): 0.153949
# 	 partial train loss (single batch): 0.152208
# 	 partial train loss (single batch): 0.151349
# 	 partial train loss (single batch): 0.150910
# 	 partial train loss (single batch): 0.145733
# 	 partial train loss (single batch): 0.144567
# 	 partial train loss (single batch): 0.143737
# 	 partial train loss (single batch): 0.144322
# 	 partial train loss (single batch): 0.144850
# 	 partial train loss (single batch): 0.141233
# 	 partial train loss (single batch): 0.142214
# 	 partial train loss (single batch): 0.141073
# 	 partial train loss (single batch): 0.142754
# 	 partial train loss (single batch): 0.140300
# 	 partial train loss (single batch): 0.137116
# 	 partial train loss (single batch): 0.138319
# 	 partial train loss (single batch): 0.136704
# 	 partial train loss (single batch): 0.138872
# 	 partial train loss (single batch): 0.134255
# 	 partial train loss (single batch): 0.135357
# 	 partial train loss (single batch): 0.135379
# 	 partial train loss (single batch): 0.132180
# 	 partial train loss (single batch): 0.131260
# 	 partial train loss (single batch): 0.131548
# 	 partial train loss (single batch): 0.128219
# 	 partial train loss (single batch): 0.129621
# 	 partial train loss (single batch): 0.127329
# 	 partial train loss (single batch): 0.129561
# 	 partial train loss (single batch): 0.124051
# 	 partial train loss (single batch): 0.122141
# 	 partial train loss (single batch): 0.126194
# 	 partial train loss (single batch): 0.123978
# 	 partial train loss (single batch): 0.121236
# 	 partial train loss (single batch): 0.123643
# 	 partial train loss (single batch): 0.122504
# 	 partial train loss (single batch): 0.118719
# 	 partial train loss (single batch): 0.119141
# 	 partial train loss (single batch): 0.119664
# 	 partial train loss (single batch): 0.116211
# 	 partial train loss (single batch): 0.117487
# 	 partial train loss (single batch): 0.116689
# 	 partial train loss (single batch): 0.112620
# 	 partial train loss (single batch): 0.118667
# 	 partial train loss (single batch): 0.114037
# 	 partial train loss (single batch): 0.112816
# 	 partial train loss (single batch): 0.112959
# 	 partial train loss (single batch): 0.113511
# 	 partial train loss (single batch): 0.109644
# 	 partial train loss (single batch): 0.112598
# 	 partial train loss (single batch): 0.107549
# 	 partial train loss (single batch): 0.107934
# 	 partial train loss (single batch): 0.112012
# 	 partial train loss (single batch): 0.104637
# 	 partial train loss (single batch): 0.105769
# 	 partial train loss (single batch): 0.109467
# 	 partial train loss (single batch): 0.102217
# 	 partial train loss (single batch): 0.101514
# 	 partial train loss (single batch): 0.105453
# 	 partial train loss (single batch): 0.102875
# 	 partial train loss (single batch): 0.101346
# 	 partial train loss (single batch): 0.102612
# 	 partial train loss (single batch): 0.100447
# 	 partial train loss (single batch): 0.100648
# 	 partial train loss (single batch): 0.098703
# 	 partial train loss (single batch): 0.101913
# 	 partial train loss (single batch): 0.097367
# 	 partial train loss (single batch): 0.097805
# 	 partial train loss (single batch): 0.095204
# 	 partial train loss (single batch): 0.092175
# 	 partial train loss (single batch): 0.093368
# 	 partial train loss (single batch): 0.092677
# 	 partial train loss (single batch): 0.092027
# 	 partial train loss (single batch): 0.090693
# 	 partial train loss (single batch): 0.091620
# 	 partial train loss (single batch): 0.092696
# 	 partial train loss (single batch): 0.086986
# 	 partial train loss (single batch): 0.086778
# 	 partial train loss (single batch): 0.090085
# 	 partial train loss (single batch): 0.088681
# 	 partial train loss (single batch): 0.084047
# 	 partial train loss (single batch): 0.086037
# 	 partial train loss (single batch): 0.085552
# 	 partial train loss (single batch): 0.085182
# 	 partial train loss (single batch): 0.085076
# 	 partial train loss (single batch): 0.083517
# 	 partial train loss (single batch): 0.082859
# 	 partial train loss (single batch): 0.084399
# 	 partial train loss (single batch): 0.080580
# 	 partial train loss (single batch): 0.081262
# 	 partial train loss (single batch): 0.082078
# 	 partial train loss (single batch): 0.079814
# 	 partial train loss (single batch): 0.078685
# 	 partial train loss (single batch): 0.079959
# 	 partial train loss (single batch): 0.076232
# 	 partial train loss (single batch): 0.075831
# 	 partial train loss (single batch): 0.074578
# 	 partial train loss (single batch): 0.075637
# 	 partial train loss (single batch): 0.075015
# 	 partial train loss (single batch): 0.074877
# 	 partial train loss (single batch): 0.074789
# 	 partial train loss (single batch): 0.073619
# 	 partial train loss (single batch): 0.073210
# 	 partial train loss (single batch): 0.072995
# 	 partial train loss (single batch): 0.071145
# 	 partial train loss (single batch): 0.071563
# 	 partial train loss (single batch): 0.072933
# 	 partial train loss (single batch): 0.069765
# 	 partial train loss (single batch): 0.069440
# 	 partial train loss (single batch): 0.070590
# 	 partial train loss (single batch): 0.067127
# 	 partial train loss (single batch): 0.070351
# 	 partial train loss (single batch): 0.067601
# 	 partial train loss (single batch): 0.066267
# 	 partial train loss (single batch): 0.066707
# 	 partial train loss (single batch): 0.065866
# 	 partial train loss (single batch): 0.069233
# 	 partial train loss (single batch): 0.065147
# 	 partial train loss (single batch): 0.064564
# 	 partial train loss (single batch): 0.064925
# 	 partial train loss (single batch): 0.065003
# 	 partial train loss (single batch): 0.064759
# 	 partial train loss (single batch): 0.064392
# 	 partial train loss (single batch): 0.064056
# 	 partial train loss (single batch): 0.063438
# 	 partial train loss (single batch): 0.060961
# 	 partial train loss (single batch): 0.063180
# 	 partial train loss (single batch): 0.061776
# 	 partial train loss (single batch): 0.061651
# 	 partial train loss (single batch): 0.061049
# 	 partial train loss (single batch): 0.061788
# 	 partial train loss (single batch): 0.058936
# 	 partial train loss (single batch): 0.059542
# 	 partial train loss (single batch): 0.059575
# 	 partial train loss (single batch): 0.058151
# 	 partial train loss (single batch): 0.058495
# 	 partial train loss (single batch): 0.057432
# 	 partial train loss (single batch): 0.058123
# 	 partial train loss (single batch): 0.057994
# 	 partial train loss (single batch): 0.057142
# 	 partial train loss (single batch): 0.057372
# 	 partial train loss (single batch): 0.055668
# 	 partial train loss (single batch): 0.056072
# 	 partial train loss (single batch): 0.055275
# 	 partial train loss (single batch): 0.057095
#
#  EPOCH 1/30 	 train loss 0.117 	 val loss 0.055
# 	 partial train loss (single batch): 0.056779
# 	 partial train loss (single batch): 0.053222
# 	 partial train loss (single batch): 0.056340
# 	 partial train loss (single batch): 0.053972
# 	 partial train loss (single batch): 0.054900
# 	 partial train loss (single batch): 0.053360
# 	 partial train loss (single batch): 0.050766
# 	 partial train loss (single batch): 0.052084
# 	 partial train loss (single batch): 0.053776
# 	 partial train loss (single batch): 0.051076
# 	 partial train loss (single batch): 0.052456
# 	 partial train loss (single batch): 0.052610
# 	 partial train loss (single batch): 0.051159
# 	 partial train loss (single batch): 0.051131
# 	 partial train loss (single batch): 0.051452
# 	 partial train loss (single batch): 0.050341
# 	 partial train loss (single batch): 0.049835
# 	 partial train loss (single batch): 0.049926
# 	 partial train loss (single batch): 0.050165
# 	 partial train loss (single batch): 0.049364
# 	 partial train loss (single batch): 0.049728
# 	 partial train loss (single batch): 0.049657
# 	 partial train loss (single batch): 0.047607
# 	 partial train loss (single batch): 0.050309
# 	 partial train loss (single batch): 0.047835
# 	 partial train loss (single batch): 0.046752
# 	 partial train loss (single batch): 0.046709
# 	 partial train loss (single batch): 0.047203
# 	 partial train loss (single batch): 0.047598
# 	 partial train loss (single batch): 0.046471
# 	 partial train loss (single batch): 0.046298
# 	 partial train loss (single batch): 0.044826
# 	 partial train loss (single batch): 0.047883
# 	 partial train loss (single batch): 0.045439
# 	 partial train loss (single batch): 0.044721
# 	 partial train loss (single batch): 0.048134
# 	 partial train loss (single batch): 0.044061
# 	 partial train loss (single batch): 0.045956
# 	 partial train loss (single batch): 0.044899
# 	 partial train loss (single batch): 0.045236
# 	 partial train loss (single batch): 0.045436
# 	 partial train loss (single batch): 0.044843
# 	 partial train loss (single batch): 0.045356
# 	 partial train loss (single batch): 0.042253
# 	 partial train loss (single batch): 0.043961
# 	 partial train loss (single batch): 0.043699
# 	 partial train loss (single batch): 0.043072
# 	 partial train loss (single batch): 0.044161
# 	 partial train loss (single batch): 0.041484
# 	 partial train loss (single batch): 0.040898
# 	 partial train loss (single batch): 0.041442
# 	 partial train loss (single batch): 0.042184
# 	 partial train loss (single batch): 0.042167
# 	 partial train loss (single batch): 0.041279
# 	 partial train loss (single batch): 0.042292
# 	 partial train loss (single batch): 0.041347
# 	 partial train loss (single batch): 0.042284
# 	 partial train loss (single batch): 0.041745
# 	 partial train loss (single batch): 0.042213
# 	 partial train loss (single batch): 0.041157
# 	 partial train loss (single batch): 0.041508
# 	 partial train loss (single batch): 0.041513
# 	 partial train loss (single batch): 0.040904
# 	 partial train loss (single batch): 0.039808
# 	 partial train loss (single batch): 0.041539
# 	 partial train loss (single batch): 0.041011
# 	 partial train loss (single batch): 0.040021
# 	 partial train loss (single batch): 0.039489
# 	 partial train loss (single batch): 0.038343
# 	 partial train loss (single batch): 0.039586
# 	 partial train loss (single batch): 0.039514
# 	 partial train loss (single batch): 0.040315
# 	 partial train loss (single batch): 0.039019
# 	 partial train loss (single batch): 0.038523
# 	 partial train loss (single batch): 0.040060
# 	 partial train loss (single batch): 0.039116
# 	 partial train loss (single batch): 0.037376
# 	 partial train loss (single batch): 0.037318
# 	 partial train loss (single batch): 0.037766
# 	 partial train loss (single batch): 0.039140
# 	 partial train loss (single batch): 0.038132
# 	 partial train loss (single batch): 0.038602
# 	 partial train loss (single batch): 0.037593
# 	 partial train loss (single batch): 0.037398
# 	 partial train loss (single batch): 0.037177
# 	 partial train loss (single batch): 0.037017
# 	 partial train loss (single batch): 0.038758
# 	 partial train loss (single batch): 0.036155
# 	 partial train loss (single batch): 0.037337
# 	 partial train loss (single batch): 0.036818
# 	 partial train loss (single batch): 0.037545
# 	 partial train loss (single batch): 0.036242
# 	 partial train loss (single batch): 0.037565
# 	 partial train loss (single batch): 0.035268
# 	 partial train loss (single batch): 0.036739
# 	 partial train loss (single batch): 0.037651
# 	 partial train loss (single batch): 0.035317
# 	 partial train loss (single batch): 0.036024
# 	 partial train loss (single batch): 0.037009
# 	 partial train loss (single batch): 0.034680
# 	 partial train loss (single batch): 0.035537
# 	 partial train loss (single batch): 0.036855
# 	 partial train loss (single batch): 0.036301
# 	 partial train loss (single batch): 0.035430
# 	 partial train loss (single batch): 0.035526
# 	 partial train loss (single batch): 0.035333
# 	 partial train loss (single batch): 0.036067
# 	 partial train loss (single batch): 0.035003
# 	 partial train loss (single batch): 0.036836
# 	 partial train loss (single batch): 0.035114
# 	 partial train loss (single batch): 0.035634
# 	 partial train loss (single batch): 0.035369
# 	 partial train loss (single batch): 0.032675
# 	 partial train loss (single batch): 0.035464
# 	 partial train loss (single batch): 0.033733
# 	 partial train loss (single batch): 0.034451
# 	 partial train loss (single batch): 0.033249
# 	 partial train loss (single batch): 0.034288
# 	 partial train loss (single batch): 0.034557
# 	 partial train loss (single batch): 0.033673
# 	 partial train loss (single batch): 0.031916
# 	 partial train loss (single batch): 0.035435
# 	 partial train loss (single batch): 0.034403
# 	 partial train loss (single batch): 0.032344
# 	 partial train loss (single batch): 0.033730
# 	 partial train loss (single batch): 0.033462
# 	 partial train loss (single batch): 0.034248
# 	 partial train loss (single batch): 0.033525
# 	 partial train loss (single batch): 0.033218
# 	 partial train loss (single batch): 0.032862
# 	 partial train loss (single batch): 0.035338
# 	 partial train loss (single batch): 0.033599
# 	 partial train loss (single batch): 0.034646
# 	 partial train loss (single batch): 0.033944
# 	 partial train loss (single batch): 0.032881
# 	 partial train loss (single batch): 0.032956
# 	 partial train loss (single batch): 0.033566
# 	 partial train loss (single batch): 0.032069
# 	 partial train loss (single batch): 0.031640
# 	 partial train loss (single batch): 0.032670
# 	 partial train loss (single batch): 0.031573
# 	 partial train loss (single batch): 0.032566
# 	 partial train loss (single batch): 0.032058
# 	 partial train loss (single batch): 0.031143
# 	 partial train loss (single batch): 0.033510
# 	 partial train loss (single batch): 0.031673
# 	 partial train loss (single batch): 0.031757
# 	 partial train loss (single batch): 0.031452
# 	 partial train loss (single batch): 0.032243
# 	 partial train loss (single batch): 0.033394
# 	 partial train loss (single batch): 0.032099
# 	 partial train loss (single batch): 0.031484
# 	 partial train loss (single batch): 0.032123
# 	 partial train loss (single batch): 0.030555
# 	 partial train loss (single batch): 0.032093
# 	 partial train loss (single batch): 0.031564
# 	 partial train loss (single batch): 0.030961
# 	 partial train loss (single batch): 0.030654
# 	 partial train loss (single batch): 0.030500
# 	 partial train loss (single batch): 0.033291
# 	 partial train loss (single batch): 0.030370
# 	 partial train loss (single batch): 0.030701
# 	 partial train loss (single batch): 0.030542
# 	 partial train loss (single batch): 0.031162
# 	 partial train loss (single batch): 0.031812
# 	 partial train loss (single batch): 0.032191
# 	 partial train loss (single batch): 0.030428
# 	 partial train loss (single batch): 0.031401
# 	 partial train loss (single batch): 0.030872
# 	 partial train loss (single batch): 0.031457
# 	 partial train loss (single batch): 0.031079
# 	 partial train loss (single batch): 0.031197
# 	 partial train loss (single batch): 0.031617
# 	 partial train loss (single batch): 0.031842
# 	 partial train loss (single batch): 0.029959
# 	 partial train loss (single batch): 0.030378
# 	 partial train loss (single batch): 0.029564
# 	 partial train loss (single batch): 0.030135
# 	 partial train loss (single batch): 0.030249
# 	 partial train loss (single batch): 0.030265
# 	 partial train loss (single batch): 0.031039
# 	 partial train loss (single batch): 0.030933
# 	 partial train loss (single batch): 0.032422
# 	 partial train loss (single batch): 0.030708
# 	 partial train loss (single batch): 0.029968
# 	 partial train loss (single batch): 0.030578
# 	 partial train loss (single batch): 0.029832
# 	 partial train loss (single batch): 0.031167
#
#  EPOCH 2/30 	 train loss 0.038 	 val loss 0.030
# 	 partial train loss (single batch): 0.031027
# 	 partial train loss (single batch): 0.029346
# 	 partial train loss (single batch): 0.031583
# 	 partial train loss (single batch): 0.029816
# 	 partial train loss (single batch): 0.030073
# 	 partial train loss (single batch): 0.030062
# 	 partial train loss (single batch): 0.028294
# 	 partial train loss (single batch): 0.029427
# 	 partial train loss (single batch): 0.030187
# 	 partial train loss (single batch): 0.029099
# 	 partial train loss (single batch): 0.029762
# 	 partial train loss (single batch): 0.030742
# 	 partial train loss (single batch): 0.030210
# 	 partial train loss (single batch): 0.028946
# 	 partial train loss (single batch): 0.031123
# 	 partial train loss (single batch): 0.028896
# 	 partial train loss (single batch): 0.028869
# 	 partial train loss (single batch): 0.030756
# 	 partial train loss (single batch): 0.029522
# 	 partial train loss (single batch): 0.028956
# 	 partial train loss (single batch): 0.028926
# 	 partial train loss (single batch): 0.029533
# 	 partial train loss (single batch): 0.028279
# 	 partial train loss (single batch): 0.030219
# 	 partial train loss (single batch): 0.028460
# 	 partial train loss (single batch): 0.028175
# 	 partial train loss (single batch): 0.027607
# 	 partial train loss (single batch): 0.028921
# 	 partial train loss (single batch): 0.028854
# 	 partial train loss (single batch): 0.027925
# 	 partial train loss (single batch): 0.028424
# 	 partial train loss (single batch): 0.027599
# 	 partial train loss (single batch): 0.030230
# 	 partial train loss (single batch): 0.028369
# 	 partial train loss (single batch): 0.027179
# 	 partial train loss (single batch): 0.029983
# 	 partial train loss (single batch): 0.028593
# 	 partial train loss (single batch): 0.029362
# 	 partial train loss (single batch): 0.028563
# 	 partial train loss (single batch): 0.029485
# 	 partial train loss (single batch): 0.029451
# 	 partial train loss (single batch): 0.029129
# 	 partial train loss (single batch): 0.029557
# 	 partial train loss (single batch): 0.027185
# 	 partial train loss (single batch): 0.028532
# 	 partial train loss (single batch): 0.028333
# 	 partial train loss (single batch): 0.027278
# 	 partial train loss (single batch): 0.029327
# 	 partial train loss (single batch): 0.027242
# 	 partial train loss (single batch): 0.026660
# 	 partial train loss (single batch): 0.027489
# 	 partial train loss (single batch): 0.028412
# 	 partial train loss (single batch): 0.027949
# 	 partial train loss (single batch): 0.027768
# 	 partial train loss (single batch): 0.028426
# 	 partial train loss (single batch): 0.027635
# 	 partial train loss (single batch): 0.028209
# 	 partial train loss (single batch): 0.028045
# 	 partial train loss (single batch): 0.029523
# 	 partial train loss (single batch): 0.027607
# 	 partial train loss (single batch): 0.028559
# 	 partial train loss (single batch): 0.028066
# 	 partial train loss (single batch): 0.027867
# 	 partial train loss (single batch): 0.026832
# 	 partial train loss (single batch): 0.028552
# 	 partial train loss (single batch): 0.028706
# 	 partial train loss (single batch): 0.027553
# 	 partial train loss (single batch): 0.026835
# 	 partial train loss (single batch): 0.026553
# 	 partial train loss (single batch): 0.027382
# 	 partial train loss (single batch): 0.028144
# 	 partial train loss (single batch): 0.028594
# 	 partial train loss (single batch): 0.027464
# 	 partial train loss (single batch): 0.027792
# 	 partial train loss (single batch): 0.028377
# 	 partial train loss (single batch): 0.027889
# 	 partial train loss (single batch): 0.026631
# 	 partial train loss (single batch): 0.025785
# 	 partial train loss (single batch): 0.026493
# 	 partial train loss (single batch): 0.028930
# 	 partial train loss (single batch): 0.027478
# 	 partial train loss (single batch): 0.028162
# 	 partial train loss (single batch): 0.027300
# 	 partial train loss (single batch): 0.026899
# 	 partial train loss (single batch): 0.026668
# 	 partial train loss (single batch): 0.027447
# 	 partial train loss (single batch): 0.028265
# 	 partial train loss (single batch): 0.026044
# 	 partial train loss (single batch): 0.027403
# 	 partial train loss (single batch): 0.026939
# 	 partial train loss (single batch): 0.027489
# 	 partial train loss (single batch): 0.026707
# 	 partial train loss (single batch): 0.027965
# 	 partial train loss (single batch): 0.026008
# 	 partial train loss (single batch): 0.027349
# 	 partial train loss (single batch): 0.027168
# 	 partial train loss (single batch): 0.026593
# 	 partial train loss (single batch): 0.026996
# 	 partial train loss (single batch): 0.027220
# 	 partial train loss (single batch): 0.025745
# 	 partial train loss (single batch): 0.027234
# 	 partial train loss (single batch): 0.027605
# 	 partial train loss (single batch): 0.027518
# 	 partial train loss (single batch): 0.026497
# 	 partial train loss (single batch): 0.026567
# 	 partial train loss (single batch): 0.026562
# 	 partial train loss (single batch): 0.027250
# 	 partial train loss (single batch): 0.026353
# 	 partial train loss (single batch): 0.027906
# 	 partial train loss (single batch): 0.026536
# 	 partial train loss (single batch): 0.027025
# 	 partial train loss (single batch): 0.027262
# 	 partial train loss (single batch): 0.024548
# 	 partial train loss (single batch): 0.027630
# 	 partial train loss (single batch): 0.025596
# 	 partial train loss (single batch): 0.026561
# 	 partial train loss (single batch): 0.025361
# 	 partial train loss (single batch): 0.026496
# 	 partial train loss (single batch): 0.026230
# 	 partial train loss (single batch): 0.026420
# 	 partial train loss (single batch): 0.024150
# 	 partial train loss (single batch): 0.027693
# 	 partial train loss (single batch): 0.026589
# 	 partial train loss (single batch): 0.025224
# 	 partial train loss (single batch): 0.026241
# 	 partial train loss (single batch): 0.025966
# 	 partial train loss (single batch): 0.027018
# 	 partial train loss (single batch): 0.025927
# 	 partial train loss (single batch): 0.025973
# 	 partial train loss (single batch): 0.025500
# 	 partial train loss (single batch): 0.028191
# 	 partial train loss (single batch): 0.026792
# 	 partial train loss (single batch): 0.027548
# 	 partial train loss (single batch): 0.026652
# 	 partial train loss (single batch): 0.025918
# 	 partial train loss (single batch): 0.026241
# 	 partial train loss (single batch): 0.026429
# 	 partial train loss (single batch): 0.025563
# 	 partial train loss (single batch): 0.025000
# 	 partial train loss (single batch): 0.026487
# 	 partial train loss (single batch): 0.024814
# 	 partial train loss (single batch): 0.025770
# 	 partial train loss (single batch): 0.025571
# 	 partial train loss (single batch): 0.024342
# 	 partial train loss (single batch): 0.027247
# 	 partial train loss (single batch): 0.025229
# 	 partial train loss (single batch): 0.025269
# 	 partial train loss (single batch): 0.025397
# 	 partial train loss (single batch): 0.026166
# 	 partial train loss (single batch): 0.026851
# 	 partial train loss (single batch): 0.026091
# 	 partial train loss (single batch): 0.025171
# 	 partial train loss (single batch): 0.026058
# 	 partial train loss (single batch): 0.024667
# 	 partial train loss (single batch): 0.025847
# 	 partial train loss (single batch): 0.025459
# 	 partial train loss (single batch): 0.025640
# 	 partial train loss (single batch): 0.024861
# 	 partial train loss (single batch): 0.024654
# 	 partial train loss (single batch): 0.027185
# 	 partial train loss (single batch): 0.024560
# 	 partial train loss (single batch): 0.024951
# 	 partial train loss (single batch): 0.024656
# 	 partial train loss (single batch): 0.025382
# 	 partial train loss (single batch): 0.026142
# 	 partial train loss (single batch): 0.026606
# 	 partial train loss (single batch): 0.024412
# 	 partial train loss (single batch): 0.025844
# 	 partial train loss (single batch): 0.025488
# 	 partial train loss (single batch): 0.025807
# 	 partial train loss (single batch): 0.025479
# 	 partial train loss (single batch): 0.025740
# 	 partial train loss (single batch): 0.026383
# 	 partial train loss (single batch): 0.026636
# 	 partial train loss (single batch): 0.024703
# 	 partial train loss (single batch): 0.024916
# 	 partial train loss (single batch): 0.024056
# 	 partial train loss (single batch): 0.024589
# 	 partial train loss (single batch): 0.025151
# 	 partial train loss (single batch): 0.025195
# 	 partial train loss (single batch): 0.025920
# 	 partial train loss (single batch): 0.025903
# 	 partial train loss (single batch): 0.027540
# 	 partial train loss (single batch): 0.025518
# 	 partial train loss (single batch): 0.024676
# 	 partial train loss (single batch): 0.025648
# 	 partial train loss (single batch): 0.024757
# 	 partial train loss (single batch): 0.025910
#
#  EPOCH 3/30 	 train loss 0.027 	 val loss 0.025
# 	 partial train loss (single batch): 0.025873
# 	 partial train loss (single batch): 0.024463
# 	 partial train loss (single batch): 0.026505
# 	 partial train loss (single batch): 0.025010
# 	 partial train loss (single batch): 0.024936
# 	 partial train loss (single batch): 0.025422
# 	 partial train loss (single batch): 0.023931
# 	 partial train loss (single batch): 0.024784
# 	 partial train loss (single batch): 0.025386
# 	 partial train loss (single batch): 0.024665
# 	 partial train loss (single batch): 0.025070
# 	 partial train loss (single batch): 0.026240
# 	 partial train loss (single batch): 0.025775
# 	 partial train loss (single batch): 0.024286
# 	 partial train loss (single batch): 0.026668
# 	 partial train loss (single batch): 0.024042
# 	 partial train loss (single batch): 0.024349
# 	 partial train loss (single batch): 0.026567
# 	 partial train loss (single batch): 0.024786
# 	 partial train loss (single batch): 0.024604
# 	 partial train loss (single batch): 0.024522
# 	 partial train loss (single batch): 0.024537
# 	 partial train loss (single batch): 0.023958
# 	 partial train loss (single batch): 0.025430
# 	 partial train loss (single batch): 0.023983
# 	 partial train loss (single batch): 0.023942
# 	 partial train loss (single batch): 0.023022
# 	 partial train loss (single batch): 0.024615
# 	 partial train loss (single batch): 0.024560
# 	 partial train loss (single batch): 0.023585
# 	 partial train loss (single batch): 0.024400
# 	 partial train loss (single batch): 0.023453
# 	 partial train loss (single batch): 0.026037
# 	 partial train loss (single batch): 0.024179
# 	 partial train loss (single batch): 0.022964
# 	 partial train loss (single batch): 0.025443
# 	 partial train loss (single batch): 0.024716
# 	 partial train loss (single batch): 0.025242
# 	 partial train loss (single batch): 0.024711
# 	 partial train loss (single batch): 0.025432
# 	 partial train loss (single batch): 0.025614
# 	 partial train loss (single batch): 0.025451
# 	 partial train loss (single batch): 0.025408
# 	 partial train loss (single batch): 0.023587
# 	 partial train loss (single batch): 0.024679
# 	 partial train loss (single batch): 0.024138
# 	 partial train loss (single batch): 0.023263
# 	 partial train loss (single batch): 0.025575
# 	 partial train loss (single batch): 0.023519
# 	 partial train loss (single batch): 0.023242
# 	 partial train loss (single batch): 0.023764
# 	 partial train loss (single batch): 0.024842
# 	 partial train loss (single batch): 0.024236
# 	 partial train loss (single batch): 0.024275
# 	 partial train loss (single batch): 0.024716
# 	 partial train loss (single batch): 0.023994
# 	 partial train loss (single batch): 0.024374
# 	 partial train loss (single batch): 0.024499
# 	 partial train loss (single batch): 0.026012
# 	 partial train loss (single batch): 0.023917
# 	 partial train loss (single batch): 0.024898
# 	 partial train loss (single batch): 0.024397
# 	 partial train loss (single batch): 0.024369
# 	 partial train loss (single batch): 0.023413
# 	 partial train loss (single batch): 0.024923
# 	 partial train loss (single batch): 0.025347
# 	 partial train loss (single batch): 0.023988
# 	 partial train loss (single batch): 0.023417
# 	 partial train loss (single batch): 0.023201
# 	 partial train loss (single batch): 0.023892
# 	 partial train loss (single batch): 0.024953
# 	 partial train loss (single batch): 0.025175
# 	 partial train loss (single batch): 0.024344
# 	 partial train loss (single batch): 0.024571
# 	 partial train loss (single batch): 0.025090
# 	 partial train loss (single batch): 0.024561
# 	 partial train loss (single batch): 0.023549
# 	 partial train loss (single batch): 0.022256
# 	 partial train loss (single batch): 0.023184
# 	 partial train loss (single batch): 0.025643
# 	 partial train loss (single batch): 0.024253
# 	 partial train loss (single batch): 0.024960
# 	 partial train loss (single batch): 0.024194
# 	 partial train loss (single batch): 0.023654
# 	 partial train loss (single batch): 0.023485
# 	 partial train loss (single batch): 0.024270
# 	 partial train loss (single batch): 0.025071
# 	 partial train loss (single batch): 0.022948
# 	 partial train loss (single batch): 0.024302
# 	 partial train loss (single batch): 0.023773
# 	 partial train loss (single batch): 0.024305
# 	 partial train loss (single batch): 0.023757
# 	 partial train loss (single batch): 0.024849
# 	 partial train loss (single batch): 0.023163
# 	 partial train loss (single batch): 0.024448
# 	 partial train loss (single batch): 0.023904
# 	 partial train loss (single batch): 0.023602
# 	 partial train loss (single batch): 0.023977
# 	 partial train loss (single batch): 0.024043
# 	 partial train loss (single batch): 0.022856
# 	 partial train loss (single batch): 0.024427
# 	 partial train loss (single batch): 0.024628
# 	 partial train loss (single batch): 0.024714
# 	 partial train loss (single batch): 0.023732
# 	 partial train loss (single batch): 0.023673
# 	 partial train loss (single batch): 0.023450
# 	 partial train loss (single batch): 0.024346
# 	 partial train loss (single batch): 0.023570
# 	 partial train loss (single batch): 0.024857
# 	 partial train loss (single batch): 0.023775
# 	 partial train loss (single batch): 0.023996
# 	 partial train loss (single batch): 0.024373
# 	 partial train loss (single batch): 0.021822
# 	 partial train loss (single batch): 0.024950
# 	 partial train loss (single batch): 0.022799
# 	 partial train loss (single batch): 0.023816
# 	 partial train loss (single batch): 0.022665
# 	 partial train loss (single batch): 0.023819
# 	 partial train loss (single batch): 0.023209
# 	 partial train loss (single batch): 0.023716
# 	 partial train loss (single batch): 0.021266
# 	 partial train loss (single batch): 0.024977
# 	 partial train loss (single batch): 0.023886
# 	 partial train loss (single batch): 0.022564
# 	 partial train loss (single batch): 0.023522
# 	 partial train loss (single batch): 0.023212
# 	 partial train loss (single batch): 0.024424
# 	 partial train loss (single batch): 0.023206
# 	 partial train loss (single batch): 0.023257
# 	 partial train loss (single batch): 0.023086
# 	 partial train loss (single batch): 0.025703
# 	 partial train loss (single batch): 0.024284
# 	 partial train loss (single batch): 0.024939
# 	 partial train loss (single batch): 0.024026
# 	 partial train loss (single batch): 0.023408
# 	 partial train loss (single batch): 0.023851
# 	 partial train loss (single batch): 0.023826
# 	 partial train loss (single batch): 0.023261
# 	 partial train loss (single batch): 0.022624
# 	 partial train loss (single batch): 0.024192
# 	 partial train loss (single batch): 0.022216
# 	 partial train loss (single batch): 0.023154
# 	 partial train loss (single batch): 0.023299
# 	 partial train loss (single batch): 0.021841
# 	 partial train loss (single batch): 0.024890
# 	 partial train loss (single batch): 0.022892
# 	 partial train loss (single batch): 0.022886
# 	 partial train loss (single batch): 0.023243
# 	 partial train loss (single batch): 0.023801
# 	 partial train loss (single batch): 0.024314
# 	 partial train loss (single batch): 0.023842
# 	 partial train loss (single batch): 0.022754
# 	 partial train loss (single batch): 0.023673
# 	 partial train loss (single batch): 0.022373
# 	 partial train loss (single batch): 0.023465
# 	 partial train loss (single batch): 0.023218
# 	 partial train loss (single batch): 0.023583
# 	 partial train loss (single batch): 0.022700
# 	 partial train loss (single batch): 0.022372
# 	 partial train loss (single batch): 0.024758
# 	 partial train loss (single batch): 0.022132
# 	 partial train loss (single batch): 0.022803
# 	 partial train loss (single batch): 0.022398
# 	 partial train loss (single batch): 0.023109
# 	 partial train loss (single batch): 0.023981
# 	 partial train loss (single batch): 0.024277
# 	 partial train loss (single batch): 0.022110
# 	 partial train loss (single batch): 0.023629
# 	 partial train loss (single batch): 0.023356
# 	 partial train loss (single batch): 0.023648
# 	 partial train loss (single batch): 0.023378
# 	 partial train loss (single batch): 0.023575
# 	 partial train loss (single batch): 0.024418
# 	 partial train loss (single batch): 0.024621
# 	 partial train loss (single batch): 0.022567
# 	 partial train loss (single batch): 0.022650
# 	 partial train loss (single batch): 0.022012
# 	 partial train loss (single batch): 0.022496
# 	 partial train loss (single batch): 0.023163
# 	 partial train loss (single batch): 0.023218
# 	 partial train loss (single batch): 0.023813
# 	 partial train loss (single batch): 0.023942
# 	 partial train loss (single batch): 0.025344
# 	 partial train loss (single batch): 0.023406
# 	 partial train loss (single batch): 0.022645
# 	 partial train loss (single batch): 0.023754
# 	 partial train loss (single batch): 0.022721
# 	 partial train loss (single batch): 0.023940
#
#  EPOCH 4/30 	 train loss 0.024 	 val loss 0.023
# 	 partial train loss (single batch): 0.023884
# 	 partial train loss (single batch): 0.022325
# 	 partial train loss (single batch): 0.024329
# 	 partial train loss (single batch): 0.023027
# 	 partial train loss (single batch): 0.022826
# 	 partial train loss (single batch): 0.023608
# 	 partial train loss (single batch): 0.022126
# 	 partial train loss (single batch): 0.022810
# 	 partial train loss (single batch): 0.023323
# 	 partial train loss (single batch): 0.022782
# 	 partial train loss (single batch): 0.023151
# 	 partial train loss (single batch): 0.024215
# 	 partial train loss (single batch): 0.023908
# 	 partial train loss (single batch): 0.022311
# 	 partial train loss (single batch): 0.024581
# 	 partial train loss (single batch): 0.022076
# 	 partial train loss (single batch): 0.022505
# 	 partial train loss (single batch): 0.024763
# 	 partial train loss (single batch): 0.022819
# 	 partial train loss (single batch): 0.022815
# 	 partial train loss (single batch): 0.022621
# 	 partial train loss (single batch): 0.022540
# 	 partial train loss (single batch): 0.022173
# 	 partial train loss (single batch): 0.023527
# 	 partial train loss (single batch): 0.022295
# 	 partial train loss (single batch): 0.022071
# 	 partial train loss (single batch): 0.021052
# 	 partial train loss (single batch): 0.022776
# 	 partial train loss (single batch): 0.022704
# 	 partial train loss (single batch): 0.021836
# 	 partial train loss (single batch): 0.022599
# 	 partial train loss (single batch): 0.021666
# 	 partial train loss (single batch): 0.024166
# 	 partial train loss (single batch): 0.022309
# 	 partial train loss (single batch): 0.021175
# 	 partial train loss (single batch): 0.023595
# 	 partial train loss (single batch): 0.023007
# 	 partial train loss (single batch): 0.023515
# 	 partial train loss (single batch): 0.022782
# 	 partial train loss (single batch): 0.023647
# 	 partial train loss (single batch): 0.023910
# 	 partial train loss (single batch): 0.023596
# 	 partial train loss (single batch): 0.023737
# 	 partial train loss (single batch): 0.022002
# 	 partial train loss (single batch): 0.022844
# 	 partial train loss (single batch): 0.022339
# 	 partial train loss (single batch): 0.021414
# 	 partial train loss (single batch): 0.023854
# 	 partial train loss (single batch): 0.021965
# 	 partial train loss (single batch): 0.021667
# 	 partial train loss (single batch): 0.022134
# 	 partial train loss (single batch): 0.023213
# 	 partial train loss (single batch): 0.022566
# 	 partial train loss (single batch): 0.022686
# 	 partial train loss (single batch): 0.023048
# 	 partial train loss (single batch): 0.022493
# 	 partial train loss (single batch): 0.022731
# 	 partial train loss (single batch): 0.022860
# 	 partial train loss (single batch): 0.024602
# 	 partial train loss (single batch): 0.022270
# 	 partial train loss (single batch): 0.023182
# 	 partial train loss (single batch): 0.022917
# 	 partial train loss (single batch): 0.022731
# 	 partial train loss (single batch): 0.021875
# 	 partial train loss (single batch): 0.023476
# 	 partial train loss (single batch): 0.023790
# 	 partial train loss (single batch): 0.022465
# 	 partial train loss (single batch): 0.021914
# 	 partial train loss (single batch): 0.021723
# 	 partial train loss (single batch): 0.022397
# 	 partial train loss (single batch): 0.023441
# 	 partial train loss (single batch): 0.023677
# 	 partial train loss (single batch): 0.022930
# 	 partial train loss (single batch): 0.023073
# 	 partial train loss (single batch): 0.023586
# 	 partial train loss (single batch): 0.022997
# 	 partial train loss (single batch): 0.022163
# 	 partial train loss (single batch): 0.020720
# 	 partial train loss (single batch): 0.021738
# 	 partial train loss (single batch): 0.024240
# 	 partial train loss (single batch): 0.022722
# 	 partial train loss (single batch): 0.023557
# 	 partial train loss (single batch): 0.022876
# 	 partial train loss (single batch): 0.022139
# 	 partial train loss (single batch): 0.022028
# 	 partial train loss (single batch): 0.022843
# 	 partial train loss (single batch): 0.023626
# 	 partial train loss (single batch): 0.021550
# 	 partial train loss (single batch): 0.022890
# 	 partial train loss (single batch): 0.022319
# 	 partial train loss (single batch): 0.022919
# 	 partial train loss (single batch): 0.022246
# 	 partial train loss (single batch): 0.023517
# 	 partial train loss (single batch): 0.021737
# 	 partial train loss (single batch): 0.023093
# 	 partial train loss (single batch): 0.022450
# 	 partial train loss (single batch): 0.022238
# 	 partial train loss (single batch): 0.022673
# 	 partial train loss (single batch): 0.022712
# 	 partial train loss (single batch): 0.021388
# 	 partial train loss (single batch): 0.023137
# 	 partial train loss (single batch): 0.023135
# 	 partial train loss (single batch): 0.023432
# 	 partial train loss (single batch): 0.022333
# 	 partial train loss (single batch): 0.022307
# 	 partial train loss (single batch): 0.021945
# 	 partial train loss (single batch): 0.023111
# 	 partial train loss (single batch): 0.022129
# 	 partial train loss (single batch): 0.023573
# 	 partial train loss (single batch): 0.022366
# 	 partial train loss (single batch): 0.022584
# 	 partial train loss (single batch): 0.023111
# 	 partial train loss (single batch): 0.020501
# 	 partial train loss (single batch): 0.023591
# 	 partial train loss (single batch): 0.021593
# 	 partial train loss (single batch): 0.022473
# 	 partial train loss (single batch): 0.021466
# 	 partial train loss (single batch): 0.022607
# 	 partial train loss (single batch): 0.021793
# 	 partial train loss (single batch): 0.022405
# 	 partial train loss (single batch): 0.020029
# 	 partial train loss (single batch): 0.023705
# 	 partial train loss (single batch): 0.022555
# 	 partial train loss (single batch): 0.021340
# 	 partial train loss (single batch): 0.022261
# 	 partial train loss (single batch): 0.021987
# 	 partial train loss (single batch): 0.023199
# 	 partial train loss (single batch): 0.021866
# 	 partial train loss (single batch): 0.021961
# 	 partial train loss (single batch): 0.021797
# 	 partial train loss (single batch): 0.024504
# 	 partial train loss (single batch): 0.023073
# 	 partial train loss (single batch): 0.023683
# 	 partial train loss (single batch): 0.022831
# 	 partial train loss (single batch): 0.022227
# 	 partial train loss (single batch): 0.022731
# 	 partial train loss (single batch): 0.022556
# 	 partial train loss (single batch): 0.022121
# 	 partial train loss (single batch): 0.021569
# 	 partial train loss (single batch): 0.023015
# 	 partial train loss (single batch): 0.020892
# 	 partial train loss (single batch): 0.021893
# 	 partial train loss (single batch): 0.022192
# 	 partial train loss (single batch): 0.020642
# 	 partial train loss (single batch): 0.023757
# 	 partial train loss (single batch): 0.021741
# 	 partial train loss (single batch): 0.021741
# 	 partial train loss (single batch): 0.022094
# 	 partial train loss (single batch): 0.022646
# 	 partial train loss (single batch): 0.023129
# 	 partial train loss (single batch): 0.022753
# 	 partial train loss (single batch): 0.021498
# 	 partial train loss (single batch): 0.022569
# 	 partial train loss (single batch): 0.021284
# 	 partial train loss (single batch): 0.022275
# 	 partial train loss (single batch): 0.022178
# 	 partial train loss (single batch): 0.022530
# 	 partial train loss (single batch): 0.021710
# 	 partial train loss (single batch): 0.021278
# 	 partial train loss (single batch): 0.023607
# 	 partial train loss (single batch): 0.021032
# 	 partial train loss (single batch): 0.021695
# 	 partial train loss (single batch): 0.021307
# 	 partial train loss (single batch): 0.022004
# 	 partial train loss (single batch): 0.022949
# 	 partial train loss (single batch): 0.023088
# 	 partial train loss (single batch): 0.020965
# 	 partial train loss (single batch): 0.022550
# 	 partial train loss (single batch): 0.022339
# 	 partial train loss (single batch): 0.022431
# 	 partial train loss (single batch): 0.022370
# 	 partial train loss (single batch): 0.022556
# 	 partial train loss (single batch): 0.023360
# 	 partial train loss (single batch): 0.023656
# 	 partial train loss (single batch): 0.021501
# 	 partial train loss (single batch): 0.021530
# 	 partial train loss (single batch): 0.021121
# 	 partial train loss (single batch): 0.021409
# 	 partial train loss (single batch): 0.022039
# 	 partial train loss (single batch): 0.022253
# 	 partial train loss (single batch): 0.022651
# 	 partial train loss (single batch): 0.022933
# 	 partial train loss (single batch): 0.024264
# 	 partial train loss (single batch): 0.022498
# 	 partial train loss (single batch): 0.021642
# 	 partial train loss (single batch): 0.022871
# 	 partial train loss (single batch): 0.021792
# 	 partial train loss (single batch): 0.022953
#
#  EPOCH 5/30 	 train loss 0.023 	 val loss 0.022
# 	 partial train loss (single batch): 0.022962
# 	 partial train loss (single batch): 0.021393
# 	 partial train loss (single batch): 0.023200
# 	 partial train loss (single batch): 0.022055
# 	 partial train loss (single batch): 0.021781
# 	 partial train loss (single batch): 0.022681
# 	 partial train loss (single batch): 0.021255
# 	 partial train loss (single batch): 0.021898
# 	 partial train loss (single batch): 0.022371
# 	 partial train loss (single batch): 0.021764
# 	 partial train loss (single batch): 0.022147
# 	 partial train loss (single batch): 0.023296
# 	 partial train loss (single batch): 0.023001
# 	 partial train loss (single batch): 0.021205
# 	 partial train loss (single batch): 0.023585
# 	 partial train loss (single batch): 0.021120
# 	 partial train loss (single batch): 0.021540
# 	 partial train loss (single batch): 0.024005
# 	 partial train loss (single batch): 0.021678
# 	 partial train loss (single batch): 0.021917
# 	 partial train loss (single batch): 0.021692
# 	 partial train loss (single batch): 0.021394
# 	 partial train loss (single batch): 0.021244
# 	 partial train loss (single batch): 0.022410
# 	 partial train loss (single batch): 0.021320
# 	 partial train loss (single batch): 0.021061
# 	 partial train loss (single batch): 0.020011
# 	 partial train loss (single batch): 0.021832
# 	 partial train loss (single batch): 0.021680
# 	 partial train loss (single batch): 0.020880
# 	 partial train loss (single batch): 0.021704
# 	 partial train loss (single batch): 0.020712
# 	 partial train loss (single batch): 0.023231
# 	 partial train loss (single batch): 0.021309
# 	 partial train loss (single batch): 0.020171
# 	 partial train loss (single batch): 0.022663
# 	 partial train loss (single batch): 0.021992
# 	 partial train loss (single batch): 0.022638
# 	 partial train loss (single batch): 0.021786
# 	 partial train loss (single batch): 0.022594
# 	 partial train loss (single batch): 0.023048
# 	 partial train loss (single batch): 0.022572
# 	 partial train loss (single batch): 0.022859
# 	 partial train loss (single batch): 0.021179
# 	 partial train loss (single batch): 0.021817
# 	 partial train loss (single batch): 0.021438
# 	 partial train loss (single batch): 0.020446
# 	 partial train loss (single batch): 0.022914
# 	 partial train loss (single batch): 0.021214
# 	 partial train loss (single batch): 0.020777
# 	 partial train loss (single batch): 0.021197
# 	 partial train loss (single batch): 0.022458
# 	 partial train loss (single batch): 0.021650
# 	 partial train loss (single batch): 0.021758
# 	 partial train loss (single batch): 0.022183
# 	 partial train loss (single batch): 0.021549
# 	 partial train loss (single batch): 0.021773
# 	 partial train loss (single batch): 0.021937
# 	 partial train loss (single batch): 0.023626
# 	 partial train loss (single batch): 0.021420
# 	 partial train loss (single batch): 0.022202
# 	 partial train loss (single batch): 0.021880
# 	 partial train loss (single batch): 0.021850
# 	 partial train loss (single batch): 0.020992
# 	 partial train loss (single batch): 0.022628
# 	 partial train loss (single batch): 0.022948
# 	 partial train loss (single batch): 0.021604
# 	 partial train loss (single batch): 0.021121
# 	 partial train loss (single batch): 0.020844
# 	 partial train loss (single batch): 0.021467
# 	 partial train loss (single batch): 0.022600
# 	 partial train loss (single batch): 0.022738
# 	 partial train loss (single batch): 0.022199
# 	 partial train loss (single batch): 0.022198
# 	 partial train loss (single batch): 0.022760
# 	 partial train loss (single batch): 0.022259
# 	 partial train loss (single batch): 0.021335
# 	 partial train loss (single batch): 0.019865
# 	 partial train loss (single batch): 0.020935
# 	 partial train loss (single batch): 0.023359
# 	 partial train loss (single batch): 0.021874
# 	 partial train loss (single batch): 0.022707
# 	 partial train loss (single batch): 0.022115
# 	 partial train loss (single batch): 0.021273
# 	 partial train loss (single batch): 0.021194
# 	 partial train loss (single batch): 0.021983
# 	 partial train loss (single batch): 0.022799
# 	 partial train loss (single batch): 0.020711
# 	 partial train loss (single batch): 0.022067
# 	 partial train loss (single batch): 0.021426
# 	 partial train loss (single batch): 0.021981
# 	 partial train loss (single batch): 0.021496
# 	 partial train loss (single batch): 0.022654
# 	 partial train loss (single batch): 0.020911
# 	 partial train loss (single batch): 0.022263
# 	 partial train loss (single batch): 0.021577
# 	 partial train loss (single batch): 0.021451
# 	 partial train loss (single batch): 0.021872
# ...
# 	 partial train loss (single batch): 0.017776
# 	 partial train loss (single batch): 0.019955
# 	 partial train loss (single batch): 0.018351
# 	 partial train loss (single batch): 0.017317
# 	 partial train loss (single batch): 0.019394
# 	 partial train loss (single batch): 0.019011
# 	 partial train loss (single batch): 0.019432
# 	 partial train loss (single batch): 0.018525
# 	 partial train loss (single batch): 0.019620
# 	 partial train loss (single batch): 0.019942
# 	 partial train loss (single batch): 0.019674
# 	 partial train loss (single batch): 0.020089
# 	 partial train loss (single batch): 0.018521
# 	 partial train loss (single batch): 0.018435
# 	 partial train loss (single batch): 0.018469
# 	 partial train loss (single batch): 0.017636
# 	 partial train loss (single batch): 0.019681
# 	 partial train loss (single batch): 0.018294
# 	 partial train loss (single batch): 0.018016
# 	 partial train loss (single batch): 0.018301
# 	 partial train loss (single batch): 0.019411
# 	 partial train loss (single batch): 0.019128
# 	 partial train loss (single batch): 0.018695
# 	 partial train loss (single batch): 0.019244
# 	 partial train loss (single batch): 0.018620
# 	 partial train loss (single batch): 0.018290
# 	 partial train loss (single batch): 0.018954
# 	 partial train loss (single batch): 0.020775
# 	 partial train loss (single batch): 0.018143
# 	 partial train loss (single batch): 0.019537
# 	 partial train loss (single batch): 0.018869
# 	 partial train loss (single batch): 0.019172
# 	 partial train loss (single batch): 0.018294
# 	 partial train loss (single batch): 0.019646
# 	 partial train loss (single batch): 0.020152
# 	 partial train loss (single batch): 0.018602
# 	 partial train loss (single batch): 0.017890
# 	 partial train loss (single batch): 0.017984
# 	 partial train loss (single batch): 0.018839
# 	 partial train loss (single batch): 0.019975
# 	 partial train loss (single batch): 0.019808
# 	 partial train loss (single batch): 0.019595
# 	 partial train loss (single batch): 0.019586
# 	 partial train loss (single batch): 0.019649
# 	 partial train loss (single batch): 0.019220
# 	 partial train loss (single batch): 0.018567
# 	 partial train loss (single batch): 0.017187
# 	 partial train loss (single batch): 0.018133
# 	 partial train loss (single batch): 0.020238
# 	 partial train loss (single batch): 0.018898
# 	 partial train loss (single batch): 0.019638
# 	 partial train loss (single batch): 0.019353
# 	 partial train loss (single batch): 0.018096
# 	 partial train loss (single batch): 0.018319
# 	 partial train loss (single batch): 0.019156
# 	 partial train loss (single batch): 0.019716
# 	 partial train loss (single batch): 0.017841
# 	 partial train loss (single batch): 0.019339
# 	 partial train loss (single batch): 0.018426
# 	 partial train loss (single batch): 0.018805
# 	 partial train loss (single batch): 0.018710
# 	 partial train loss (single batch): 0.019438
# 	 partial train loss (single batch): 0.018033
# 	 partial train loss (single batch): 0.019452
# 	 partial train loss (single batch): 0.018686
# 	 partial train loss (single batch): 0.018497
# 	 partial train loss (single batch): 0.018884
# 	 partial train loss (single batch): 0.019223
# 	 partial train loss (single batch): 0.017707
# 	 partial train loss (single batch): 0.019705
# 	 partial train loss (single batch): 0.019377
# 	 partial train loss (single batch): 0.019593
# 	 partial train loss (single batch): 0.018667
# 	 partial train loss (single batch): 0.018906
# 	 partial train loss (single batch): 0.018209
# 	 partial train loss (single batch): 0.019403
# 	 partial train loss (single batch): 0.018433
# 	 partial train loss (single batch): 0.019723
# 	 partial train loss (single batch): 0.019011
# 	 partial train loss (single batch): 0.018850
# 	 partial train loss (single batch): 0.019199
# 	 partial train loss (single batch): 0.017183
# 	 partial train loss (single batch): 0.019916
# 	 partial train loss (single batch): 0.018180
# 	 partial train loss (single batch): 0.018687
# 	 partial train loss (single batch): 0.017491
# 	 partial train loss (single batch): 0.019010
# 	 partial train loss (single batch): 0.018294
# 	 partial train loss (single batch): 0.019171
# 	 partial train loss (single batch): 0.016681
# 	 partial train loss (single batch): 0.019776
# 	 partial train loss (single batch): 0.019379
# 	 partial train loss (single batch): 0.017951
# 	 partial train loss (single batch): 0.018746
# 	 partial train loss (single batch): 0.018378
# 	 partial train loss (single batch): 0.019986
# 	 partial train loss (single batch): 0.018569
# 	 partial train loss (single batch): 0.018435
# 	 partial train loss (single batch): 0.018472
# 	 partial train loss (single batch): 0.020714
# 	 partial train loss (single batch): 0.019819
# 	 partial train loss (single batch): 0.020146
# 	 partial train loss (single batch): 0.019286
# 	 partial train loss (single batch): 0.019344
# 	 partial train loss (single batch): 0.019228
# 	 partial train loss (single batch): 0.018997
# 	 partial train loss (single batch): 0.019244
# 	 partial train loss (single batch): 0.018398
# 	 partial train loss (single batch): 0.019940
# 	 partial train loss (single batch): 0.017457
# 	 partial train loss (single batch): 0.018838
# 	 partial train loss (single batch): 0.019048
# 	 partial train loss (single batch): 0.017479
# 	 partial train loss (single batch): 0.020399
# 	 partial train loss (single batch): 0.018524
# 	 partial train loss (single batch): 0.018302
# 	 partial train loss (single batch): 0.019160
# 	 partial train loss (single batch): 0.018501
# 	 partial train loss (single batch): 0.019858
# 	 partial train loss (single batch): 0.019608
# 	 partial train loss (single batch): 0.018101
# 	 partial train loss (single batch): 0.019168
# 	 partial train loss (single batch): 0.018204
# 	 partial train loss (single batch): 0.018590
# 	 partial train loss (single batch): 0.018765
# 	 partial train loss (single batch): 0.019517
# 	 partial train loss (single batch): 0.018484
# 	 partial train loss (single batch): 0.017954
# 	 partial train loss (single batch): 0.019940
# 	 partial train loss (single batch): 0.017633
# 	 partial train loss (single batch): 0.018309
# 	 partial train loss (single batch): 0.018010
# 	 partial train loss (single batch): 0.018877
# 	 partial train loss (single batch): 0.019302
# 	 partial train loss (single batch): 0.019903
# 	 partial train loss (single batch): 0.017804
# 	 partial train loss (single batch): 0.018946
# 	 partial train loss (single batch): 0.019050
# 	 partial train loss (single batch): 0.018930
# 	 partial train loss (single batch): 0.018991
# 	 partial train loss (single batch): 0.019360
# 	 partial train loss (single batch): 0.020234
# 	 partial train loss (single batch): 0.020672
# 	 partial train loss (single batch): 0.018256
# 	 partial train loss (single batch): 0.018056
# 	 partial train loss (single batch): 0.017512
# 	 partial train loss (single batch): 0.018191
# 	 partial train loss (single batch): 0.018862
# 	 partial train loss (single batch): 0.018922
# 	 partial train loss (single batch): 0.019473
# 	 partial train loss (single batch): 0.019710
# 	 partial train loss (single batch): 0.020854
# 	 partial train loss (single batch): 0.019165
# 	 partial train loss (single batch): 0.018658
# 	 partial train loss (single batch): 0.019634
# 	 partial train loss (single batch): 0.018806
# 	 partial train loss (single batch): 0.019533
#
#  EPOCH 29/30 	 train loss 0.019 	 val loss 0.019
# 	 partial train loss (single batch): 0.019817
# 	 partial train loss (single batch): 0.018521
# 	 partial train loss (single batch): 0.019879
# 	 partial train loss (single batch): 0.018935
# 	 partial train loss (single batch): 0.018703
# 	 partial train loss (single batch): 0.019638
# 	 partial train loss (single batch): 0.018605
# 	 partial train loss (single batch): 0.018864
# 	 partial train loss (single batch): 0.018971
# 	 partial train loss (single batch): 0.018539
# 	 partial train loss (single batch): 0.019012
# 	 partial train loss (single batch): 0.020345
# 	 partial train loss (single batch): 0.020175
# 	 partial train loss (single batch): 0.017743
# 	 partial train loss (single batch): 0.020074
# 	 partial train loss (single batch): 0.018292
# 	 partial train loss (single batch): 0.018455
# 	 partial train loss (single batch): 0.020642
# 	 partial train loss (single batch): 0.018182
# 	 partial train loss (single batch): 0.018731
# 	 partial train loss (single batch): 0.018469
# 	 partial train loss (single batch): 0.017716
# 	 partial train loss (single batch): 0.018121
# 	 partial train loss (single batch): 0.019059
# 	 partial train loss (single batch): 0.018166
# 	 partial train loss (single batch): 0.017993
# 	 partial train loss (single batch): 0.016772
# 	 partial train loss (single batch): 0.018663
# 	 partial train loss (single batch): 0.018579
# 	 partial train loss (single batch): 0.017921
# 	 partial train loss (single batch): 0.018158
# 	 partial train loss (single batch): 0.017713
# 	 partial train loss (single batch): 0.019875
# 	 partial train loss (single batch): 0.018281
# 	 partial train loss (single batch): 0.017245
# 	 partial train loss (single batch): 0.019310
# 	 partial train loss (single batch): 0.018948
# 	 partial train loss (single batch): 0.019375
# 	 partial train loss (single batch): 0.018445
# 	 partial train loss (single batch): 0.019555
# 	 partial train loss (single batch): 0.019890
# 	 partial train loss (single batch): 0.019631
# 	 partial train loss (single batch): 0.020075
# 	 partial train loss (single batch): 0.018461
# 	 partial train loss (single batch): 0.018367
# 	 partial train loss (single batch): 0.018441
# 	 partial train loss (single batch): 0.017601
# 	 partial train loss (single batch): 0.019623
# 	 partial train loss (single batch): 0.018249
# 	 partial train loss (single batch): 0.017954
# 	 partial train loss (single batch): 0.018261
# 	 partial train loss (single batch): 0.019353
# 	 partial train loss (single batch): 0.019081
# 	 partial train loss (single batch): 0.018648
# 	 partial train loss (single batch): 0.019235
# 	 partial train loss (single batch): 0.018596
# 	 partial train loss (single batch): 0.018205
# 	 partial train loss (single batch): 0.018929
# 	 partial train loss (single batch): 0.020715
# 	 partial train loss (single batch): 0.018097
# 	 partial train loss (single batch): 0.019494
# 	 partial train loss (single batch): 0.018776
# 	 partial train loss (single batch): 0.019118
# 	 partial train loss (single batch): 0.018243
# 	 partial train loss (single batch): 0.019618
# 	 partial train loss (single batch): 0.020105
# 	 partial train loss (single batch): 0.018553
# 	 partial train loss (single batch): 0.017843
# 	 partial train loss (single batch): 0.017963
# 	 partial train loss (single batch): 0.018771
# 	 partial train loss (single batch): 0.019934
# 	 partial train loss (single batch): 0.019747
# 	 partial train loss (single batch): 0.019569
# 	 partial train loss (single batch): 0.019538
# 	 partial train loss (single batch): 0.019643
# 	 partial train loss (single batch): 0.019149
# 	 partial train loss (single batch): 0.018517
# 	 partial train loss (single batch): 0.017145
# 	 partial train loss (single batch): 0.018051
# 	 partial train loss (single batch): 0.020169
# 	 partial train loss (single batch): 0.018878
# 	 partial train loss (single batch): 0.019547
# 	 partial train loss (single batch): 0.019318
# 	 partial train loss (single batch): 0.018003
# 	 partial train loss (single batch): 0.018293
# 	 partial train loss (single batch): 0.019091
# 	 partial train loss (single batch): 0.019623
# 	 partial train loss (single batch): 0.017832
# 	 partial train loss (single batch): 0.019274
# 	 partial train loss (single batch): 0.018361
# 	 partial train loss (single batch): 0.018724
# 	 partial train loss (single batch): 0.018662
# 	 partial train loss (single batch): 0.019352
# 	 partial train loss (single batch): 0.017961
# 	 partial train loss (single batch): 0.019392
# 	 partial train loss (single batch): 0.018668
# 	 partial train loss (single batch): 0.018416
# 	 partial train loss (single batch): 0.018828
# 	 partial train loss (single batch): 0.019186
# 	 partial train loss (single batch): 0.017645
# 	 partial train loss (single batch): 0.019653
# 	 partial train loss (single batch): 0.019297
# 	 partial train loss (single batch): 0.019524
# 	 partial train loss (single batch): 0.018615
# 	 partial train loss (single batch): 0.018846
# 	 partial train loss (single batch): 0.018148
# 	 partial train loss (single batch): 0.019304
# 	 partial train loss (single batch): 0.018372
# 	 partial train loss (single batch): 0.019731
# 	 partial train loss (single batch): 0.018930
# 	 partial train loss (single batch): 0.018803
# 	 partial train loss (single batch): 0.019179
# 	 partial train loss (single batch): 0.017134
# 	 partial train loss (single batch): 0.019917
# 	 partial train loss (single batch): 0.018156
# 	 partial train loss (single batch): 0.018658
# 	 partial train loss (single batch): 0.017528
# 	 partial train loss (single batch): 0.019010
# 	 partial train loss (single batch): 0.018286
# 	 partial train loss (single batch): 0.019139
# 	 partial train loss (single batch): 0.016698
# 	 partial train loss (single batch): 0.019734
# 	 partial train loss (single batch): 0.019369
# 	 partial train loss (single batch): 0.017956
# 	 partial train loss (single batch): 0.018713
# 	 partial train loss (single batch): 0.018340
# 	 partial train loss (single batch): 0.019955
# 	 partial train loss (single batch): 0.018506
# 	 partial train loss (single batch): 0.018392
# 	 partial train loss (single batch): 0.018445
# 	 partial train loss (single batch): 0.020654
# 	 partial train loss (single batch): 0.019772
# 	 partial train loss (single batch): 0.020083
# 	 partial train loss (single batch): 0.019241
# 	 partial train loss (single batch): 0.019290
# 	 partial train loss (single batch): 0.019153
# 	 partial train loss (single batch): 0.018953
# 	 partial train loss (single batch): 0.019199
# 	 partial train loss (single batch): 0.018356
# 	 partial train loss (single batch): 0.019923
# 	 partial train loss (single batch): 0.017400
# 	 partial train loss (single batch): 0.018782
# 	 partial train loss (single batch): 0.019036
# 	 partial train loss (single batch): 0.017431
# 	 partial train loss (single batch): 0.020351
# 	 partial train loss (single batch): 0.018494
# 	 partial train loss (single batch): 0.018281
# 	 partial train loss (single batch): 0.019104
# 	 partial train loss (single batch): 0.018437
# 	 partial train loss (single batch): 0.019806
# 	 partial train loss (single batch): 0.019537
# 	 partial train loss (single batch): 0.018059
# 	 partial train loss (single batch): 0.019168
# 	 partial train loss (single batch): 0.018175
# 	 partial train loss (single batch): 0.018518
# 	 partial train loss (single batch): 0.018749
# 	 partial train loss (single batch): 0.019487
# 	 partial train loss (single batch): 0.018432
# 	 partial train loss (single batch): 0.017936
# 	 partial train loss (single batch): 0.019857
# 	 partial train loss (single batch): 0.017575
# 	 partial train loss (single batch): 0.018297
# 	 partial train loss (single batch): 0.017977
# 	 partial train loss (single batch): 0.018854
# 	 partial train loss (single batch): 0.019253
# 	 partial train loss (single batch): 0.019853
# 	 partial train loss (single batch): 0.017767
# 	 partial train loss (single batch): 0.018890
# 	 partial train loss (single batch): 0.018961
# 	 partial train loss (single batch): 0.018904
# 	 partial train loss (single batch): 0.018973
# 	 partial train loss (single batch): 0.019295
# 	 partial train loss (single batch): 0.020201
# 	 partial train loss (single batch): 0.020654
# 	 partial train loss (single batch): 0.018168
# 	 partial train loss (single batch): 0.018008
# 	 partial train loss (single batch): 0.017493
# 	 partial train loss (single batch): 0.018137
# 	 partial train loss (single batch): 0.018790
# 	 partial train loss (single batch): 0.018848
# 	 partial train loss (single batch): 0.019407
# 	 partial train loss (single batch): 0.019646
# 	 partial train loss (single batch): 0.020749
# 	 partial train loss (single batch): 0.019153
# 	 partial train loss (single batch): 0.018588
# 	 partial train loss (single batch): 0.019611
# 	 partial train loss (single batch): 0.018756
# 	 partial train loss (single batch): 0.019468
#
#  EPOCH 30/30 	 train loss 0.019 	 val loss 0.019

# %%
test_epoch(encoder,decoder,device,test_loader,loss_fn).item()
# Out:
# 0.019240006804466248

# %%
# Train and validation loss

plt.figure(figsize=(7,5))
plt.semilogy(history['train_loss'], label='Train')
plt.semilogy(history['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
#plt.grid()
plt.legend()
#plt.title('loss')
plt.show()

# %%
def show_image(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

def show_top_n(encoder, decoder, dataset, n=10):
    encoder.eval()
    decoder.eval()

    with torch.no_grad():
        # calculate mean and std of latent code, generated takining in test images as inputs 
        images, labels = map(list, zip(*[dataset[i] for i in range(10)]))
        images = torch.stack(images).to(device)
        latent = encoder(images)
        latent = latent.cpu()

        mean = latent.mean(dim=0)
        print(mean)
        std = (latent - mean).pow(2).mean(dim=0).sqrt()
        print(std)

        # sample latent vectors from the normal distribution
        latent = torch.randn(128, dim)*std + mean

        # reconstruct images from the random latent vectors
        latent = latent.to(device)
        img_recon = decoder(latent)
        img_recon = img_recon.cpu()

        fig, ax = plt.subplots(figsize=(20, 8.5))
        show_image(torchvision.utils.make_grid(img_recon[:100],10,5))
        plt.show()
        
show_top_n(encoder, decoder, test_dataset, n=10)
# Out:
# tensor([-0.3652, -0.0589,  0.8125,  0.1935])
# tensor([0.5865, 0.7306, 0.8967, 0.4532])
